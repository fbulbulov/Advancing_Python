# %%
import numpy as np

# %%
import pandas as pd

# %%
a = np.array([[1,2,3],[1,1,1]]) 
b = np.array([[5,5,5],[2,2,2]])

# %%
a
b
# Out:
# array([[5, 5, 5],
#        [2, 2, 2]])

# %%
np.shape(a)
# Out:
# (2, 3)

# %%
a.shape
# Out:
# (2, 3)

# %%
a*b
# Out:
# array([[ 5, 10, 15],
#        [ 2,  2,  2]])

# %%
import matplotlib.pyplot as plt

# %%
a=np.array([1,2,3])
b=np.array([0,2,0])

# %%
plt.plot(a)

# %%
plt.plot(b)

# %%
plt.plot(a)
plt.plot(b)

# %%
a="HELLO"
a.lower()
# Out:
# 'hello'

# %%
a=np.array()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2327ac5a89fb> in <module>
# ----> 1 a=np.array()
#
# TypeError: array() missing required argument 'object' (pos 1)

# %%
Given the ndarray a = [1,2,3,4,5,6,7,8,9] what will the a[:7][1:] return?
# Out:
# Object `return` not found.

# %%
a = np.array([1,2,3])
b = np.array([1,1,1])
np.inner(a,b)
# Out:
# 6
